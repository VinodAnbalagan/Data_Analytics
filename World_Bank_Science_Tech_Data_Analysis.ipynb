# %% [markdown]
# <a href="https://colab.research.google.com/github/VinodAnbalagan/Data_Analytics/blob/main/World_Bank_Science_Tech_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## World Bank Science and Technology Data Analysis

# %% [markdown]
# **Importing the Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
st_data_2018 = pd.read_csv("/content/science_tech_2018.csv")
st_data_2018.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           0.049514
# 2         Algeria                                                NaN
# 3  American Samoa                                                NaN
# 4         Andorra                                          28.460560
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                               591717.0                         3713.0
# 2                                    NaN                         9490.0
# 3                                    NaN                            NaN
# 4                             33913480.0                         1180.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %%
st_data_2018.info()
st_data_2018.shape
st_data_2018.size
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Country Name                                         219 non-null    object
#  1   High-technology exports (% of manufactured exports)  132 non-null    float64
#  2   High-technology exports (current US$)                131 non-null    float64
#  3   Trademark applications, total                        133 non-null    float64
#  4   Trademark applications, direct resident              128 non-null    float64
#  5   Trademark applications, direct nonresident           129 non-null    float64
#  6   Patent applications, residents                       118 non-null    float64
#  7   Patent applications, nonresidents                    119 non-null    float64
# ...

# %%
st_data_2018.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
st_data_2009 = pd.read_csv("/content/science_tech_2009.csv")
st_data_2009.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           1.328024
# 2         Algeria                                           0.653887
# 3  American Samoa                                                NaN
# 4         Andorra                                          12.192161
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                             10128935.0                         3456.0
# 2                              4616076.0                         5345.0
# 3                                    NaN                            NaN
# 4                             10402350.0                          785.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %%
st_data_2009.info()
st_data_2009.shape
st_data_2009.size
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Country Name                                         219 non-null    object
#  1   High-technology exports (% of manufactured exports)  131 non-null    float64
#  2   High-technology exports (current US$)                131 non-null    float64
#  3   Trademark applications, total                        111 non-null    float64
#  4   Trademark applications, direct resident              101 non-null    float64
#  5   Trademark applications, direct nonresident           101 non-null    float64
#  6   Patent applications, residents                       93 non-null     float64
#  7   Patent applications, nonresidents                    101 non-null    float64
# ...

# %%
st_data_2009.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %% [markdown]
# ## Cleaning the Data
#
# ### Missing Data

# %%
st_data_2018.isnull().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     87
# High-technology exports (current US$)                   88
# Trademark applications, total                           86
# Trademark applications, direct resident                 91
# Trademark applications, direct nonresident              90
# Patent applications, residents                         101
# Patent applications, nonresidents                      100
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        146
# dtype: int64

# %%
st_data_2018_clean = st_data_2018.dropna()
st_data_2018_clean.isnull().sum()
# Out:
# Country Name                                           0
# High-technology exports (% of manufactured exports)    0
# High-technology exports (current US$)                  0
# Trademark applications, total                          0
# Trademark applications, direct resident                0
# Trademark applications, direct nonresident             0
# Patent applications, residents                         0
# Patent applications, nonresidents                      0
# Scientific and technical journal articles              0
# Research and development expenditure (% of GDP)        0
# dtype: int64

# %%
st_data_2009.isnull().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     88
# High-technology exports (current US$)                   88
# Trademark applications, total                          108
# Trademark applications, direct resident                118
# Trademark applications, direct nonresident             118
# Patent applications, residents                         126
# Patent applications, nonresidents                      118
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        122
# dtype: int64

# %%
st_data_2018_clean.shape
# Out:
# (51, 10)

# %%
st_data_2009_clean = st_data_2009.dropna()
st_data_2009_clean.isnull().sum()
# Out:
# Country Name                                           0
# High-technology exports (% of manufactured exports)    0
# High-technology exports (current US$)                  0
# Trademark applications, total                          0
# Trademark applications, direct resident                0
# Trademark applications, direct nonresident             0
# Patent applications, residents                         0
# Patent applications, nonresidents                      0
# Scientific and technical journal articles              0
# Research and development expenditure (% of GDP)        0
# dtype: int64

# %%
st_data_2009_clean.shape
# Out:
# (56, 10)

# %% [markdown]
# ## Exploratory Data Analysis
#
# ### Descriptive Statistics

# %%
# Display descriptive statistics for the cleaned 2018 data
#pd.set_option('display.float.format', lambda x:'%.3f'%x)
st_data_2018_clean.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a001" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a001_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_1a001_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_1a001_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_1a001_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_1a001_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_1a001_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_1a001_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
# ...

# %%
#pd.set_option('display.float.format', lambda x:'%.3f'%x)
st_data_2009_clean.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6736" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6736_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_a6736_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_a6736_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_a6736_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_a6736_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_a6736_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_a6736_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
# ...

# %%
sns.boxplot(x=st_data_2009_clean["High-technology exports (% of manufactured exports)"]);

# %%
sns.boxplot(x=st_data_2018_clean["High-technology exports (% of manufactured exports)"]);

# %% [markdown]
# ##Outliers

# %%
columns = st_data_2018_clean.columns

for col in columns:
  sns.boxplot(x=st_data_2018_clean[col])
  plt.xticks(rotation=45, ha='right', fontsize=6)  # Added fontsize=8
  plt.show()

# %%
article_max = st_data_2018_clean["Scientific and technical journal articles"].max()
article_max
# Out:
# 422807.71

# %%
st_data_2018_clean[st_data_2018_clean["Scientific and technical journal articles"] == article_max]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                       156365524736.000                     464786.000
#
#      Trademark applications, direct resident  \
# 207                               342150.000
#
#      Trademark applications, direct nonresident  \
# 207                                  122636.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                      285095.000                         312046.000
#
#      Scientific and technical journal articles  \
# 207                                 422807.710
#
#      Research and development expenditure (% of GDP)
# 207                                            2.838

# %%
st_data_2018_clean[st_data_2018_clean["Scientific and technical journal articles"] > 60000]
# Out:
#            Country Name  High-technology exports (% of manufactured exports)  \
# 68               France                                             25.920
# 73              Germany                                             15.778
# 89                India                                              9.008
# 96                Italy                                              7.505
# 98                Japan                                             17.268
# 104         Korea, Rep.                                             36.347
# 161  Russian Federation                                             10.963
# 206      United Kingdom                                             22.643
# 207       United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 68                        117814412441.000                      98279.000
# ...

# %%
columns = st_data_2009_clean.columns

for col in columns:
  sns.boxplot(x=st_data_2009_clean[col])
  plt.xticks(rotation=45, ha='right', fontsize=6)  # Added fontsize=8
  plt.show()

# %%
article_max = st_data_2009_clean["Scientific and technical journal articles"].max()
article_max
# Out:
# 399350.31

# %%
st_data_2009_clean[st_data_2009_clean["Scientific and technical journal articles"] == article_max]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                             25.010
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                       154108484413.000                     265943.000
#
#      Trademark applications, direct resident  \
# 207                               225045.000
#
#      Trademark applications, direct nonresident  \
# 207                                   40898.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                      224912.000                         231194.000
#
#      Scientific and technical journal articles  \
# 207                                 399350.310
#
#      Research and development expenditure (% of GDP)
# 207                                            2.813

# %%
st_data_2009_clean[st_data_2009_clean["Scientific and technical journal articles"] > 60000]
# Out:
#        Country Name  High-technology exports (% of manufactured exports)  \
# 41            China                                             31.952
# 68           France                                             24.380
# 73          Germany                                             16.882
# 98            Japan                                             20.586
# 178      South Asia                                              8.310
# 206  United Kingdom                                             20.804
# 207   United States                                             25.010
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 41                        359273932009.000                     806906.000
# 68                         88872522741.000                      83901.000
# 73                        159207939862.000                      74370.000
# 98                        104428943952.000                     109614.000
# ...

# %%
# Subset for 2009 data with articles > 60000
df_2009_high_articles = st_data_2009_clean[st_data_2009_clean["Scientific and technical journal articles"] > 60000]

# Subset for 2018 data with articles > 60000
df_2018_high_articles = st_data_2018_clean[st_data_2018_clean["Scientific and technical journal articles"] > 60000]

# %%
# Merge the two subsets on 'Country Name'
merged_df = pd.merge(df_2009_high_articles, df_2018_high_articles, on='Country Name', suffixes=('_2009', '_2018'))

# %%
# Calculate the difference between 2018 and 2009 for all columns
for col in df_2009_high_articles.columns:
    if col != 'Country Name':  # Exclude 'Country Name' from difference calculation
        merged_df[col + '_diff'] = merged_df[col + '_2018'] - merged_df[col + '_2009']

# %%
# Sort by the absolute difference in 'Scientific and technical journal articles'
# and display the top countries
top_countries = merged_df.sort_values(by=['Scientific and technical journal articles_diff'], ascending=False)

# Display the top countries with the differences
top_countries[['Country Name'] + [col for col in merged_df.columns if '_diff' in col]]
# Out:
#      Country Name  High-technology exports (% of manufactured exports)_diff  \
# 4   United States                                             -6.114
# 1         Germany                                             -1.104
# 3  United Kingdom                                              1.840
# 0          France                                              1.540
# 2           Japan                                             -3.318
#
#    High-technology exports (current US$)_diff  \
# 4                              2257040323.000
# 1                             50874367318.000
# 3                             27484090075.000
# 0                             28941889700.000
# 2                              6591499643.000
#
#    Trademark applications, total_diff  \
# 4                          198843.000
# 1                             866.000
# 3                           61069.000
# 0                           14378.000
# 2                           74043.000
#
# ...

# %%
# Select the top N countries for the bar chart (e.g., top 10)
top_n = 10  # Adjust as needed
top_countries_chart = top_countries.head(top_n)

# Create the bar chart using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Country Name', y='Scientific and technical journal articles_diff',
            hue='Country Name', data=top_countries_chart, palette='viridis', legend=False)
plt.xlabel("Country Name")
plt.ylabel("Change in Scientific and technical journal articles")
plt.title("Top {} Countries with Most Significant Increase in Articles (2009-2018)".format(top_n))
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show();

# %% [markdown]
# ##Exploring Relationships
#
# ###Correlations

# %%
st_data_2018_clean.select_dtypes(include=np.number).corr(method='pearson').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_30283_row0_col0, #T_30283_row1_col1, #T_30283_row2_col2, #T_30283_row3_col3, #T_30283_row4_col4, #T_30283_row5_col5, #T_30283_row6_col6, #T_30283_row7_col7, #T_30283_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_30283_row0_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_30283_row0_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_30283_row0_col3, #T_30283_row8_col1, #T_30283_row8_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_30283_row0_col4, #T_30283_row8_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_30283_row0_col5, #T_30283_row0_col6, #T_30283_row0_col7, #T_30283_row4_col8, #T_30283_row6_col0, #T_30283_row6_col1, #T_30283_row8_col2, #T_30283_row8_col3, #T_30283_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_30283_row0_col8 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_30283_row1_col0 {
# ...

# %%
st_data_2018_clean.select_dtypes(include=np.number).corr(method='spearman').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_54d05_row0_col0, #T_54d05_row1_col1, #T_54d05_row2_col2, #T_54d05_row3_col3, #T_54d05_row4_col4, #T_54d05_row5_col5, #T_54d05_row6_col6, #T_54d05_row7_col7, #T_54d05_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_54d05_row0_col1, #T_54d05_row8_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_54d05_row0_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_54d05_row0_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_54d05_row0_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_54d05_row0_col5, #T_54d05_row0_col6, #T_54d05_row0_col7, #T_54d05_row4_col0, #T_54d05_row4_col1, #T_54d05_row4_col8, #T_54d05_row8_col2, #T_54d05_row8_col3, #T_54d05_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_54d05_row0_col8, #T_54d05_row7_col6 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_54d05_row1_col0, #T_54d05_row2_col5 {
# ...

# %%
st_data_2018_clean.plot(kind='scatter', x='High-technology exports (% of manufactured exports)', y='Scientific and technical journal articles', alpha=0.5);

# %% [markdown]
# US is an outlier, so lets remove US from the equation to get a closer look.

# %%
st_data_2018_nonUS = st_data_2018_clean[st_data_2018_clean["Country Name"] != "United States"]
st_data_2018_nonUS.plot(kind='scatter', x='High-technology exports (% of manufactured exports)', y='Scientific and technical journal articles', alpha=0.5);

# %%
st_data_2009_clean.select_dtypes(include=np.number).corr(method='pearson').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_2c00d_row0_col0, #T_2c00d_row1_col1, #T_2c00d_row2_col2, #T_2c00d_row2_col3, #T_2c00d_row3_col2, #T_2c00d_row3_col3, #T_2c00d_row4_col4, #T_2c00d_row5_col5, #T_2c00d_row6_col6, #T_2c00d_row7_col7, #T_2c00d_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2c00d_row0_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_2c00d_row0_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_2c00d_row0_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_2c00d_row0_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_2c00d_row0_col5, #T_2c00d_row0_col6, #T_2c00d_row0_col7, #T_2c00d_row3_col0, #T_2c00d_row3_col8, #T_2c00d_row8_col1, #T_2c00d_row8_col2, #T_2c00d_row8_col3, #T_2c00d_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2c00d_row0_col8, #T_2c00d_row1_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_2c00d_row1_col2, #T_2c00d_row3_col4 {
# ...

# %%
st_data_2009_clean.select_dtypes(include=np.number).corr(method='spearman').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f849a_row0_col0, #T_f849a_row1_col1, #T_f849a_row2_col2, #T_f849a_row3_col3, #T_f849a_row4_col4, #T_f849a_row5_col5, #T_f849a_row6_col6, #T_f849a_row7_col7, #T_f849a_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f849a_row0_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_f849a_row0_col2, #T_f849a_row0_col3, #T_f849a_row0_col5, #T_f849a_row0_col7, #T_f849a_row3_col0, #T_f849a_row4_col1, #T_f849a_row4_col8, #T_f849a_row8_col4, #T_f849a_row8_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f849a_row0_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f849a_row0_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_f849a_row0_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f849a_row1_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_f849a_row1_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_f849a_row1_col3 {
# ...

# %%
st_data_2018_clean.plot(kind='scatter', x='High-technology exports (% of manufactured exports)', y='Scientific and technical journal articles', alpha=0.5);

# %%
st_data_2018_nonUS = st_data_2018_clean[st_data_2018_clean["Country Name"] != "United States"]
st_data_2018_nonUS.plot(kind='scatter', x='High-technology exports (% of manufactured exports)', y='Scientific and technical journal articles', alpha=0.5);

# %% [markdown]
# ## T-Tests

# %%
import scipy.stats as stats

# %%
stats.ttest_ind(st_data_2018_clean["High-technology exports (% of manufactured exports)"], st_data_2009_clean["High-technology exports (% of manufactured exports)"])
# Out:
# TtestResult(statistic=-1.5178124850425097, pvalue=0.13206686889029143, df=105.0)

# %%
# Create an empty list to store the results
results = []

# Iterate through the columns and perform t-tests
for i in range(1, len(columns)):
    col_name = columns[i]
    a = st_data_2018_clean[col_name]
    b = st_data_2009_clean[col_name]
    t_stat, p_value = stats.ttest_ind(a, b)  # Get t-statistic and p-value

    # Append the results to the list
    results.append([col_name, t_stat, p_value])

# Create a pandas DataFrame from the results list
results_df = pd.DataFrame(results, columns=['Variable', 'T-Statistic', 'P-Value'])

# Display the DataFrame as a table
display(results_df)
# Out:
#                                             Variable  T-Statistic  P-Value
# 0  High-technology exports (% of manufactured exp...       -1.518    0.132
# 1              High-technology exports (current US$)       -0.123    0.903
# 2                      Trademark applications, total       -0.270    0.787
# 3            Trademark applications, direct resident       -0.388    0.699
# 4         Trademark applications, direct nonresident        0.486    0.628
# 5                     Patent applications, residents       -0.171    0.865
# 6                  Patent applications, nonresidents        0.045    0.964
# 7          Scientific and technical journal articles        0.006    0.995
# 8    Research and development expenditure (% of GDP)        0.280    0.780
